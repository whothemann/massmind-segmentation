# %% [markdown]
# # MassMIND Architecture Probe — Kaggle
#
# Trains four `VGG16UNetExt` configurations sequentially on Kaggle (P100):
#
# | tag | attention gates | transformer bottleneck |
# |---|---|---|
# | `base`      | ❌ | ❌ |
# | `att`       | ✅ | ❌ |
# | `trans`     | ❌ | ✅ |
# | `att_trans` | ✅ | ✅ |
#
# Defaults: 600 training images, 10 epochs/config, batch 8, focal loss (γ=2), augmentation A.
# Estimated total runtime: **2–3 h on P100**.
#
# ### Usage
# 1. Pin GPU to **P100** (Settings → Accelerator). T4×2 is *slower* on FP32 single-GPU.
# 2. Enable **Internet** (Settings → Internet on; needs one-time phone verification).
# 3. Save your **GitHub PAT** as a Kaggle Secret named `github_pat`
#    (Add-ons → Secrets). Required only if the repo is private.
# 4. **Save Version → Save & Run All** to run unattended. The 4 configs
#    take ~2–3 h; closing the browser tab is fine.
# 5. After completion, grab artifacts from the **Output tab** of the version.

# %% [markdown]
# ## 0. Config — edit me

# %%
# Repository
REPO_URL_HTTPS = 'https://github.com/whothemann/massmind-segmentation.git'  # <-- EDIT if forked
REPO_BRANCH    = 'main'
REPO_DIR       = '/kaggle/working/massmind-segmentation'

# Probe hyperparameters (passed straight to scripts/probe_architectures.py)
EPOCHS       = 10
SUBSET       = 600
BATCH_SIZE   = 8       # P100 has 16 GB; transformer variant has the tightest VRAM budget
NUM_WORKERS  = 4       # Kaggle gives ~4 vCPUs per session
AUGMENTATION = 'A'
LOSS         = 'focal'
FOCAL_GAMMA  = 2.0
LR           = 1e-4
SEED         = 42

# Run a 30-second wiring check on a tiny subset before the long probe.
# Highly recommended -- catches OOM / NaN / wiring bugs before 2 h of compute.
RUN_SMOKE_TEST = False

# Comma-separated subset of {base, att, trans, att_trans}. Use to resume
# after a crash, e.g. CONFIGS = 'trans,att_trans'.
CONFIGS = 'att,att_trans'

# Probe outputs are written here, then visible in the Kaggle Output tab.
import time
PROBE_OUTPUT_DIR = f'/kaggle/working/probe_{int(time.time())}'
print('Probe output dir:', PROBE_OUTPUT_DIR)
# Out:
# Probe output dir: /kaggle/working/probe_1778856284

# %% [markdown]
# ## 1. GPU + environment
#
# Verify we got a P100 and not a T4. If you see T4 here, kill the session and
# re-pick P100 in Settings before burning compute time.

# %%
import os
import platform
import torch

print('Python      :', platform.python_version())
print('Torch       :', torch.__version__)
print('CUDA build  :', torch.version.cuda)
print('CUDA avail  :', torch.cuda.is_available())
if torch.cuda.is_available():
    name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f'Device      : {name}')
    print(f'VRAM        : {vram:.1f} GB')
    if 'T4' in name:
        print('\nWARNING: T4 detected. P100 is recommended for this workload.')
else:
    raise RuntimeError('No CUDA device available -- switch on the GPU in Settings.')

# !nvidia-smi --query-gpu=name,memory.total,memory.used,driver_version --format=csv
# Out:
# Python      : 3.12.12
# Torch       : 2.10.0+cu128
# CUDA build  : 12.8
# CUDA avail  : True
# Device      : Tesla T4
# VRAM        : 15.6 GB
#
# WARNING: T4 detected. P100 is recommended for this workload.
# name, memory.total [MiB], memory.used [MiB], driver_version
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08

# %% [markdown]
# ## 2. Clone repository
#
# Reads the GitHub PAT from the Kaggle Secret `github_pat` if present;
# otherwise prompts interactively (won't work in headless Save & Run All).
# Public repos work without any token — leave the secret empty.

# %%
import os
import subprocess
from pathlib import Path


def _get_pat():
    """Look up the PAT from a Kaggle Secret; return empty string if not set."""
    try:
        from kaggle_secrets import UserSecretsClient
        return UserSecretsClient().get_secret('github_pat').strip()
    except Exception:
        # Either not on Kaggle, or the secret isn't configured. That's fine for
        # a public repo. For a private repo on a headless run, configure the
        # secret in Add-ons -> Secrets before re-running.
        return ''


if Path(REPO_DIR).exists():
    print(f'{REPO_DIR} already present -- pulling latest from {REPO_BRANCH}')
    subprocess.run(['git', '-C', REPO_DIR, 'fetch', 'origin'], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'checkout', REPO_BRANCH], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'pull', '--ff-only'], check=True)
else:
    pat = _get_pat()
    if pat:
        auth_url = REPO_URL_HTTPS.replace('https://', f'https://x-access-token:{pat}@')
    else:
        auth_url = REPO_URL_HTTPS
    subprocess.run(['git', 'clone', '-b', REPO_BRANCH, auth_url, REPO_DIR], check=True)
    # Strip the token from the remote so it isn't persisted in .git/config.
    subprocess.run(
        ['git', '-C', REPO_DIR, 'remote', 'set-url', 'origin', REPO_URL_HTTPS], check=True
    )
    del pat, auth_url

os.chdir(REPO_DIR)
print('cwd:', os.getcwd())
subprocess.run(['git', 'log', '-1', '--oneline'], check=True)
# Out:
# /kaggle/working/massmind-segmentation already present -- pulling latest from main
# From https://github.com/whothemann/massmind-segmentation
#    7c834fd..1b0a138  main       -> origin/main
# Already on 'main'
# Your branch is behind 'origin/main' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# Updating 7c834fd..1b0a138
# Fast-forward
#  base_metrics.csv                                   | 11 +++++
#  ...training-probe-test-attention-transformer.ipynb |  1 +
#  scripts/probe_architectures.py                     | 19 ++++++++-
#  src/train.py                                       | 49 ++++++++++++++++++----
#  trans_metrics.csv                                  | 11 +++++
#  5 files changed, 82 insertions(+), 9 deletions(-)
#  create mode 100644 base_metrics.csv
#  create mode 100644 kaggle_training-probe-test-attention-transformer.ipynb
#  create mode 100644 trans_metrics.csv
# cwd: /kaggle/working/massmind-segmentation
# 1b0a138 add results of test train of unet with transformer (attention failed), add AMP mixed-precision to trainer (opt-in) + default-on for probe
# CompletedProcess(args=['git', 'log', '-1', '--oneline'], returncode=0)

# %% [markdown]
# ## 3. Install dependencies
#
# `--upgrade-strategy only-if-needed` keeps Kaggle's pre-installed PyTorch in place
# (reinstalling can silently downgrade to a CPU build).

# %%
# !pip install -q --upgrade-strategy only-if-needed -r requirements.txt

# Verify the install didn't switch us off CUDA.
import torch
assert torch.cuda.is_available(), 'CUDA broke after pip install -- check torch version.'
print('Torch CUDA still works:', torch.cuda.get_device_name(0))
# Out:
# Torch CUDA still works: Tesla T4

# %% [markdown]
# ## 4. Download dataset + prepare splits + stats
#
# All three steps are idempotent: if the data is already on disk, they skip the heavy work.
# First run: ~2 min download + ~30 s splits/stats. Subsequent runs: a few seconds.

# %%
# !python scripts/download.py
# !python -m src.splits
# !python -m src.stats
# Out:
# 2026-05-15 14:44:49,373 INFO __main__: Dataset already present under /kaggle/working/massmind-segmentation/data/massmind — skipping download.
# 2026-05-15 14:44:49,665 INFO __main__: Found 2916 paired image/mask files.
# 2026-05-15 14:44:49,675 INFO __main__: Stratifying across 26 capture sessions.
# 2026-05-15 14:44:49,677 INFO __main__: Wrote split to /kaggle/working/massmind-segmentation/data/splits/split.json
# 2026-05-15 14:44:49,677 INFO __main__:   train=2042  val=583  test=291
# 2026-05-15 14:44:50,000 INFO __main__: Computing mean/std over 2042 training images
# stats: 100%|██████████████████████████████| 2042/2042 [00:10<00:00, 191.95img/s]
# 2026-05-15 14:45:00,647 INFO __main__: mean = 0.506746
# 2026-05-15 14:45:00,647 INFO __main__: std  = 0.195996
# 2026-05-15 14:45:00,647 INFO __main__: Wrote stats to /kaggle/working/massmind-segmentation/data/splits/stats.json

# %% [markdown]
# ## 5. Smoke test (optional but recommended)
#
# Runs one `base` config on 8 images / 1 epoch — proves the whole pipeline wires up
# before committing to a multi-hour run. Skipped if `RUN_SMOKE_TEST = False` above.

# %%
import subprocess

if RUN_SMOKE_TEST:
    cmd = [
        'python', '-u', 'scripts/probe_architectures.py',
        '--subset', '8', '--epochs', '1', '--batch-size', '2',
        '--num-workers', str(NUM_WORKERS),
        '--device', 'cuda',
        '--configs', 'base',
        '--output-dir', '/kaggle/working/smoke_test',
    ]
    print('Running smoke test:', ' '.join(cmd))
    subprocess.run(cmd, check=True)
    print('\nSmoke test passed -- proceeding to the full probe.')
else:
    print('Smoke test skipped (RUN_SMOKE_TEST = False).')
# Out:
# Smoke test skipped (RUN_SMOKE_TEST = False).

# %% [markdown]
# ## 6. Full probe — 4 configurations
#
# Sequential training of all four configs into `PROBE_OUTPUT_DIR`. Each config
# writes its own `metrics.csv`, `checkpoint_best.pt`, `checkpoint_last.pt`, and
# `config.json`. A top-level `summary.json` aggregates best val mIoU per config.
#
# Progress is logged line-by-line. **Each line is also visible in the Kaggle log
# tab** while "Save & Run All" is running, so you can monitor without keeping
# the browser tab open.

# %%
import subprocess
import time

cmd = [
    'python', '-u', 'scripts/probe_architectures.py',
    '--epochs', str(EPOCHS),
    '--subset', str(SUBSET),
    '--batch-size', str(BATCH_SIZE),
    '--num-workers', str(NUM_WORKERS),
    '--lr', str(LR),
    '--augmentation', AUGMENTATION,
    '--loss', LOSS,
    '--focal-gamma', str(FOCAL_GAMMA),
    '--seed', str(SEED),
    '--device', 'cuda',
    '--configs', CONFIGS,
    '--output-dir', PROBE_OUTPUT_DIR,
]

print('Launching probe:')
print(' ', ' '.join(cmd))
print()

t0 = time.time()
result = subprocess.run(cmd)
elapsed_min = (time.time() - t0) / 60
print(f'\nProbe finished in {elapsed_min:.1f} min  (exit code = {result.returncode})')
if result.returncode != 0:
    print('WARNING: at least one config failed; check summary.json for details.')
# Out:
# Launching probe:
#   python -u scripts/probe_architectures.py --epochs 10 --subset 600 --batch-size 8 --num-workers 4 --lr 0.0001 --augmentation A --loss focal --focal-gamma 2.0 --seed 42 --device cuda --configs att,att_trans --output-dir /kaggle/working/probe_1778856284
# 2026-05-15 14:45:06,294 INFO probe: ==============================================================================
# 2026-05-15 14:45:06,294 INFO probe: Architecture probe: 2 config(s)  device=cuda  epochs=10  subset=600  batch=8  loss=focal  aug=A  amp=True
# 2026-05-15 14:45:06,294 INFO probe: Output: /kaggle/working/probe_1778856284
# 2026-05-15 14:45:06,295 INFO probe: ==============================================================================
# 2026-05-15 14:45:06,295 INFO probe:
# 2026-05-15 14:45:06,295 INFO probe: [1/2] att  (attention=True, transformer=False)
# 2026-05-15 14:45:06,295 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 14:45:06,296 INFO src.train: Device: cuda
# 2026-05-15 14:45:06,297 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 14:45:06,361 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 14:45:08,189 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-15 14:45:08,373 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=False, att_gates=True, params=39.28M (trainable=39.28M)
# 2026-05-15 14:46:33,337 INFO src.train: epoch  1/10  train_loss=0.4411  val_loss=0.2233  mIoU=0.4597  pixel_acc=0.9333  (84.7s)
# 2026-05-15 14:46:33,517 INFO src.train:   saved new best (mIoU=0.4597)
# 2026-05-15 14:48:09,962 INFO src.train: epoch  2/10  train_loss=0.1647  val_loss=0.1347  mIoU=0.5039  pixel_acc=0.9555  (96.4s)
# 2026-05-15 14:48:10,270 INFO src.train:   saved new best (mIoU=0.5039)
# 2026-05-15 14:49:46,553 INFO src.train: epoch  3/10  train_loss=0.1253  val_loss=0.1031  mIoU=0.5105  pixel_acc=0.9571  (96.3s)
# 2026-05-15 14:49:46,853 INFO src.train:   saved new best (mIoU=0.5105)
# 2026-05-15 14:51:23,169 INFO src.train: epoch  4/10  train_loss=0.0996  val_loss=0.0888  mIoU=0.5409  pixel_acc=0.9623  (96.3s)
# 2026-05-15 14:51:23,469 INFO src.train:   saved new best (mIoU=0.5409)
# 2026-05-15 14:52:59,495 INFO src.train: epoch  5/10  train_loss=0.0860  val_loss=0.0842  mIoU=0.5350  pixel_acc=0.9595  (96.0s)
# 2026-05-15 14:54:36,015 INFO src.train: epoch  6/10  train_loss=0.0712  val_loss=0.0686  mIoU=0.5657  pixel_acc=0.9672  (96.5s)
# 2026-05-15 14:54:36,310 INFO src.train:   saved new best (mIoU=0.5657)
# 2026-05-15 14:56:12,621 INFO src.train: epoch  7/10  train_loss=0.0637  val_loss=0.0656  mIoU=0.5751  pixel_acc=0.9679  (96.3s)
# 2026-05-15 14:56:12,912 INFO src.train:   saved new best (mIoU=0.5751)
# 2026-05-15 14:57:49,317 INFO src.train: epoch  8/10  train_loss=0.0544  val_loss=0.0596  mIoU=0.6025  pixel_acc=0.9698  (96.4s)
# 2026-05-15 14:57:49,619 INFO src.train:   saved new best (mIoU=0.6025)
# 2026-05-15 14:59:26,153 INFO src.train: epoch  9/10  train_loss=0.0498  val_loss=0.0596  mIoU=0.6164  pixel_acc=0.9704  (96.5s)
# 2026-05-15 14:59:26,434 INFO src.train:   saved new best (mIoU=0.6164)
# 2026-05-15 15:01:03,066 INFO src.train: epoch 10/10  train_loss=0.0503  val_loss=0.0585  mIoU=0.6198  pixel_acc=0.9703  (96.6s)
# 2026-05-15 15:01:03,330 INFO src.train:   saved new best (mIoU=0.6198)
# 2026-05-15 15:01:03,506 INFO src.train: Training complete. Best val mIoU=0.6198
# 2026-05-15 15:01:03,728 INFO probe: [1/2] att done in 16.0 min  best mIoU = 0.6198
# 2026-05-15 15:01:03,806 INFO probe:
# 2026-05-15 15:01:03,806 INFO probe: [2/2] att_trans  (attention=True, transformer=True)
# 2026-05-15 15:01:03,807 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 15:01:03,807 INFO src.train: Device: cuda
# 2026-05-15 15:01:03,814 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 15:01:03,816 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 15:01:05,496 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# /kaggle/working/massmind-segmentation/src/models/_transformer_bottleneck.py:77: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 2026-05-15 15:01:05,624 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=True, att_gates=True, params=38.80M (trainable=38.80M)
# 2026-05-15 15:02:43,501 INFO src.train: epoch  1/10  train_loss=0.4840  val_loss=0.2116  mIoU=0.4548  pixel_acc=0.9323  (97.8s)
# 2026-05-15 15:02:43,699 INFO src.train:   saved new best (mIoU=0.4548)
# 2026-05-15 15:04:20,574 INFO src.train: epoch  2/10  train_loss=0.1861  val_loss=0.1349  mIoU=0.5063  pixel_acc=0.9557  (96.9s)
# 2026-05-15 15:04:20,881 INFO src.train:   saved new best (mIoU=0.5063)
# 2026-05-15 15:05:57,836 INFO src.train: epoch  3/10  train_loss=0.1192  val_loss=0.1048  mIoU=0.5166  pixel_acc=0.9587  (97.0s)
# 2026-05-15 15:05:58,140 INFO src.train:   saved new best (mIoU=0.5166)
# 2026-05-15 15:07:34,455 INFO src.train: epoch  4/10  train_loss=0.1088  val_loss=0.0860  mIoU=0.5600  pixel_acc=0.9622  (96.3s)
# 2026-05-15 15:07:34,744 INFO src.train:   saved new best (mIoU=0.5600)
# 2026-05-15 15:09:11,605 INFO src.train: epoch  5/10  train_loss=0.0828  val_loss=0.0790  mIoU=0.5259  pixel_acc=0.9612  (96.9s)
# 2026-05-15 15:10:48,642 INFO src.train: epoch  6/10  train_loss=0.0724  val_loss=0.0749  mIoU=0.5890  pixel_acc=0.9627  (97.0s)
# 2026-05-15 15:10:48,942 INFO src.train:   saved new best (mIoU=0.5890)
# 2026-05-15 15:12:24,837 INFO src.train: epoch  7/10  train_loss=0.0609  val_loss=0.0613  mIoU=0.6137  pixel_acc=0.9683  (95.9s)
# 2026-05-15 15:12:25,143 INFO src.train:   saved new best (mIoU=0.6137)
# 2026-05-15 15:14:01,994 INFO src.train: epoch  8/10  train_loss=0.0524  val_loss=0.0651  mIoU=0.6145  pixel_acc=0.9644  (96.9s)
# 2026-05-15 15:14:02,264 INFO src.train:   saved new best (mIoU=0.6145)
# 2026-05-15 15:15:39,117 INFO src.train: epoch  9/10  train_loss=0.0514  val_loss=0.0610  mIoU=0.6205  pixel_acc=0.9686  (96.9s)
# 2026-05-15 15:15:39,386 INFO src.train:   saved new best (mIoU=0.6205)
# 2026-05-15 15:17:16,484 INFO src.train: epoch 10/10  train_loss=0.0483  val_loss=0.0598  mIoU=0.6236  pixel_acc=0.9679  (97.1s)
# 2026-05-15 15:17:16,748 INFO src.train:   saved new best (mIoU=0.6236)
# 2026-05-15 15:17:16,924 INFO src.train: Training complete. Best val mIoU=0.6236
# 2026-05-15 15:17:17,192 INFO probe: [2/2] att_trans done in 16.2 min  best mIoU = 0.6236
# 2026-05-15 15:17:17,274 INFO probe:
# 2026-05-15 15:17:17,275 INFO probe: ==============================================================================
# 2026-05-15 15:17:17,275 INFO probe: Probe complete in 32.2 min
# 2026-05-15 15:17:17,275 INFO probe:
# 2026-05-15 15:17:17,275 INFO probe: config     | attention | transformer | best mIoU | time min | status
# 2026-05-15 15:17:17,275 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 15:17:17,275 INFO probe: att        | True      | False       | 0.6198    |     16.0 | ok
# 2026-05-15 15:17:17,275 INFO probe: att_trans  | True      | True        | 0.6236    |     16.2 | ok
# 2026-05-15 15:17:17,275 INFO probe: ==============================================================================
# 2026-05-15 15:17:17,275 INFO probe: Summary saved to /kaggle/working/probe_1778856284/summary.json
# Probe finished in 32.3 min  (exit code = 0)

# %% [markdown]
# ## 7. Summary table + training curves
#
# Loads `summary.json` and the per-config `metrics.csv` files, prints a comparison
# table, and plots train/val loss + val mIoU per epoch for each config.

# %%
import json
from pathlib import Path

import pandas as pd

summary = json.loads(Path(PROBE_OUTPUT_DIR, 'summary.json').read_text())

rows = []
for r in summary['results']:
    rows.append({
        'config':       r['tag'],
        'attention':    r['use_attention_gates'],
        'transformer':  r['use_transformer_bottleneck'],
        'best_mIoU':    r['best_val_miou'],
        'time (min)':   round(r['elapsed_s'] / 60, 1),
        'status':       r['status'],
    })
df = pd.DataFrame(rows)
print(df.to_string(index=False))

print(f"\nTotal probe time: {summary['elapsed_total_s']/60:.1f} min")
# Out:
#    config  attention  transformer  best_mIoU  time (min) status
#       att       True        False    0.61981        16.0     ok
# att_trans       True         True    0.62361        16.2     ok
#
# Total probe time: 32.2 min

# %%
import csv
from pathlib import Path

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

for r in summary['results']:
    if r['status'] != 'ok':
        continue
    metrics_csv = Path(r['config_dir']) / 'metrics.csv'
    if not metrics_csv.exists():
        continue
    epochs, tloss, vloss, mious = [], [], [], []
    with metrics_csv.open() as f:
        for row in csv.DictReader(f):
            epochs.append(int(row['epoch']))
            tloss.append(float(row['train_loss']))
            vloss.append(float(row['val_loss']))
            mious.append(float(row['mIoU']))
    axes[0].plot(epochs, vloss, marker='o', markersize=3, label=r['tag'])
    axes[1].plot(epochs, mious, marker='o', markersize=3, label=r['tag'])

axes[0].set_title('val loss');  axes[0].set_xlabel('epoch'); axes[0].set_ylabel('loss')
axes[1].set_title('val mIoU'); axes[1].set_xlabel('epoch'); axes[1].set_ylabel('mIoU')
for ax in axes:
    ax.grid(alpha=0.3); ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Per-class IoU breakdown
#
# MassMIND's interesting question is `living_obs` (0.05 % of pixels). The summary
# table only shows mIoU; this cell pulls the per-class IoU at each config's best epoch.

# %%
import csv
from pathlib import Path

import pandas as pd

CLASS_NAMES = ['sky', 'water', 'bridge', 'obstacle', 'living_obs', 'background', 'self']

per_class_rows = []
for r in summary['results']:
    if r['status'] != 'ok':
        continue
    metrics_csv = Path(r['config_dir']) / 'metrics.csv'
    if not metrics_csv.exists():
        continue
    best_row = None
    best_miou = -1.0
    with metrics_csv.open() as f:
        for row in csv.DictReader(f):
            v = float(row['mIoU'])
            if v > best_miou:
                best_miou = v
                best_row = row
    if best_row is None:
        continue
    entry = {'config': r['tag'], 'epoch': int(best_row['epoch']), 'mIoU': best_miou}
    for name in CLASS_NAMES:
        entry[name] = float(best_row.get(f'iou_{name}', float('nan')))
    per_class_rows.append(entry)

per_class = pd.DataFrame(per_class_rows)
print(per_class.to_string(index=False))
# Out:
#    config  epoch    mIoU     sky   water  bridge  obstacle  living_obs  background    self
#       att     10 0.61981 0.98481 0.98288 0.40954   0.22175         0.0     0.82636 0.91334
# att_trans     10 0.62361 0.98388 0.98138 0.38575   0.29716         0.0     0.81243 0.90466

# %% [markdown]
# ## 9. Package outputs for download
#
# Zips the probe directory into `/kaggle/working/probe_<timestamp>.zip`. The zip
# is automatically published to the **Output tab** of the saved version — click
# "Download All" to grab everything (checkpoints + metrics + summary + plots).

# %%
import shutil
from pathlib import Path

src_dir = Path(PROBE_OUTPUT_DIR)
archive = shutil.make_archive(str(src_dir), 'zip', root_dir=src_dir.parent, base_dir=src_dir.name)
print('Wrote archive:', archive)
print('Size (MB):  ', round(Path(archive).stat().st_size / 1e6, 1))
# Out:
# Wrote archive: /kaggle/working/probe_1778856284.zip
# Size (MB):   578.1
