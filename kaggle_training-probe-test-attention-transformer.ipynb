# %% [markdown]
# # MassMIND Architecture Probe — Kaggle
#
# Trains four `VGG16UNetExt` configurations sequentially on Kaggle (P100):
#
# | tag | attention gates | transformer bottleneck |
# |---|---|---|
# | `base`      | ❌ | ❌ |
# | `att`       | ✅ | ❌ |
# | `trans`     | ❌ | ✅ |
# | `att_trans` | ✅ | ✅ |
#
# Defaults: 600 training images, 10 epochs/config, batch 8, focal loss (γ=2), augmentation A.
# Estimated total runtime: **2–3 h on P100**.
#
# ### Usage
# 1. Pin GPU to **P100** (Settings → Accelerator). T4×2 is *slower* on FP32 single-GPU.
# 2. Enable **Internet** (Settings → Internet on; needs one-time phone verification).
# 3. Save your **GitHub PAT** as a Kaggle Secret named `github_pat`
#    (Add-ons → Secrets). Required only if the repo is private.
# 4. **Save Version → Save & Run All** to run unattended. The 4 configs
#    take ~2–3 h; closing the browser tab is fine.
# 5. After completion, grab artifacts from the **Output tab** of the version.

# %% [markdown]
# ## 0. Config — edit me

# %%
# Repository
REPO_URL_HTTPS = 'https://github.com/whothemann/massmind-segmentation.git'  # <-- EDIT if forked
REPO_BRANCH    = 'main'
REPO_DIR       = '/kaggle/working/massmind-segmentation'

# Probe hyperparameters (passed straight to scripts/probe_architectures.py)
EPOCHS       = 10
SUBSET       = 600
BATCH_SIZE   = 8       # P100 has 16 GB; transformer variant has the tightest VRAM budget
NUM_WORKERS  = 4       # Kaggle gives ~4 vCPUs per session
AUGMENTATION = 'A'
LOSS         = 'focal'
FOCAL_GAMMA  = 2.0
LR           = 1e-4
SEED         = 42

# Run a 30-second wiring check on a tiny subset before the long probe.
# Highly recommended -- catches OOM / NaN / wiring bugs before 2 h of compute.
RUN_SMOKE_TEST = True

# Comma-separated subset of {base, att, trans, att_trans}. Use to resume
# after a crash, e.g. CONFIGS = 'trans,att_trans'.
CONFIGS = 'base,att,trans,att_trans'

# Probe outputs are written here, then visible in the Kaggle Output tab.
import time
PROBE_OUTPUT_DIR = f'/kaggle/working/probe_{int(time.time())}'
print('Probe output dir:', PROBE_OUTPUT_DIR)
# Out:
# Probe output dir: /kaggle/working/probe_1778849646

# %% [markdown]
# ## 1. GPU + environment
#
# Verify we got a P100 and not a T4. If you see T4 here, kill the session and
# re-pick P100 in Settings before burning compute time.

# %%
import os
import platform
import torch

print('Python      :', platform.python_version())
print('Torch       :', torch.__version__)
print('CUDA build  :', torch.version.cuda)
print('CUDA avail  :', torch.cuda.is_available())
if torch.cuda.is_available():
    name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f'Device      : {name}')
    print(f'VRAM        : {vram:.1f} GB')
    if 'T4' in name:
        print('\nWARNING: T4 detected. P100 is recommended for this workload.')
else:
    raise RuntimeError('No CUDA device available -- switch on the GPU in Settings.')

# !nvidia-smi --query-gpu=name,memory.total,memory.used,driver_version --format=csv
# Out:
# Python      : 3.12.12
# Torch       : 2.10.0+cu128
# CUDA build  : 12.8
# CUDA avail  : True
# Device      : Tesla T4
# VRAM        : 15.6 GB
#
# WARNING: T4 detected. P100 is recommended for this workload.
# name, memory.total [MiB], memory.used [MiB], driver_version
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08

# %% [markdown]
# ## 2. Clone repository
#
# Reads the GitHub PAT from the Kaggle Secret `github_pat` if present;
# otherwise prompts interactively (won't work in headless Save & Run All).
# Public repos work without any token — leave the secret empty.

# %%
import os
import subprocess
from pathlib import Path


def _get_pat():
    """Look up the PAT from a Kaggle Secret; return empty string if not set."""
    try:
        from kaggle_secrets import UserSecretsClient
        return UserSecretsClient().get_secret('github_pat').strip()
    except Exception:
        # Either not on Kaggle, or the secret isn't configured. That's fine for
        # a public repo. For a private repo on a headless run, configure the
        # secret in Add-ons -> Secrets before re-running.
        return ''


if Path(REPO_DIR).exists():
    print(f'{REPO_DIR} already present -- pulling latest from {REPO_BRANCH}')
    subprocess.run(['git', '-C', REPO_DIR, 'fetch', 'origin'], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'checkout', REPO_BRANCH], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'pull', '--ff-only'], check=True)
else:
    pat = _get_pat()
    if pat:
        auth_url = REPO_URL_HTTPS.replace('https://', f'https://x-access-token:{pat}@')
    else:
        auth_url = REPO_URL_HTTPS
    subprocess.run(['git', 'clone', '-b', REPO_BRANCH, auth_url, REPO_DIR], check=True)
    # Strip the token from the remote so it isn't persisted in .git/config.
    subprocess.run(
        ['git', '-C', REPO_DIR, 'remote', 'set-url', 'origin', REPO_URL_HTTPS], check=True
    )
    del pat, auth_url

os.chdir(REPO_DIR)
print('cwd:', os.getcwd())
subprocess.run(['git', 'log', '-1', '--oneline'], check=True)
# Out:
# /kaggle/working/massmind-segmentation already present -- pulling latest from main
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# cwd: /kaggle/working/massmind-segmentation
# 7c834fd wire architecture probe into trainer + Kaggle Notebook
# CompletedProcess(args=['git', 'log', '-1', '--oneline'], returncode=0)

# %% [markdown]
# ## 3. Install dependencies
#
# `--upgrade-strategy only-if-needed` keeps Kaggle's pre-installed PyTorch in place
# (reinstalling can silently downgrade to a CPU build).

# %%
# !pip install -q --upgrade-strategy only-if-needed -r requirements.txt

# Verify the install didn't switch us off CUDA.
import torch
assert torch.cuda.is_available(), 'CUDA broke after pip install -- check torch version.'
print('Torch CUDA still works:', torch.cuda.get_device_name(0))
# Out:
# Torch CUDA still works: Tesla T4

# %% [markdown]
# ## 4. Download dataset + prepare splits + stats
#
# All three steps are idempotent: if the data is already on disk, they skip the heavy work.
# First run: ~2 min download + ~30 s splits/stats. Subsequent runs: a few seconds.

# %%
# !python scripts/download.py
# !python -m src.splits
# !python -m src.stats
# Out:
# 2026-05-15 12:54:11,851 INFO __main__: Dataset already present under /kaggle/working/massmind-segmentation/data/massmind — skipping download.
# 2026-05-15 12:54:12,110 INFO __main__: Found 2916 paired image/mask files.
# 2026-05-15 12:54:12,119 INFO __main__: Stratifying across 26 capture sessions.
# 2026-05-15 12:54:12,122 INFO __main__: Wrote split to /kaggle/working/massmind-segmentation/data/splits/split.json
# 2026-05-15 12:54:12,122 INFO __main__:   train=2042  val=583  test=291
# 2026-05-15 12:54:12,436 INFO __main__: Computing mean/std over 2042 training images
# stats: 100%|██████████████████████████████| 2042/2042 [00:10<00:00, 193.60img/s]
# 2026-05-15 12:54:22,993 INFO __main__: mean = 0.506746
# 2026-05-15 12:54:22,993 INFO __main__: std  = 0.195996
# 2026-05-15 12:54:22,993 INFO __main__: Wrote stats to /kaggle/working/massmind-segmentation/data/splits/stats.json

# %% [markdown]
# ## 5. Smoke test (optional but recommended)
#
# Runs one `base` config on 8 images / 1 epoch — proves the whole pipeline wires up
# before committing to a multi-hour run. Skipped if `RUN_SMOKE_TEST = False` above.

# %%
import subprocess

if RUN_SMOKE_TEST:
    cmd = [
        'python', '-u', 'scripts/probe_architectures.py',
        '--subset', '8', '--epochs', '1', '--batch-size', '2',
        '--num-workers', str(NUM_WORKERS),
        '--device', 'cuda',
        '--configs', 'base',
        '--output-dir', '/kaggle/working/smoke_test',
    ]
    print('Running smoke test:', ' '.join(cmd))
    subprocess.run(cmd, check=True)
    print('\nSmoke test passed -- proceeding to the full probe.')
else:
    print('Smoke test skipped (RUN_SMOKE_TEST = False).')
# Out:
# Running smoke test: python -u scripts/probe_architectures.py --subset 8 --epochs 1 --batch-size 2 --num-workers 4 --device cuda --configs base --output-dir /kaggle/working/smoke_test
# 2026-05-15 12:54:28,601 INFO probe: ==============================================================================
# 2026-05-15 12:54:28,601 INFO probe: Architecture probe: 1 config(s)  device=cuda  epochs=1  subset=8  batch=2  loss=focal  aug=A
# 2026-05-15 12:54:28,602 INFO probe: Output: /kaggle/working/smoke_test
# 2026-05-15 12:54:28,602 INFO probe: ==============================================================================
# 2026-05-15 12:54:28,602 INFO probe:
# 2026-05-15 12:54:28,602 INFO probe: [1/1] base  (attention=False, transformer=False)
# 2026-05-15 12:54:28,602 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 12:54:28,604 INFO src.train: Device: cuda
# 2026-05-15 12:54:28,605 INFO src.train: Subsetting training set to first 8 files.
# 2026-05-15 12:54:28,672 INFO src.train: train batches=4 (n=8)  val batches=4 (n=8)  norm: mean=0.5067 std=0.1960
# 2026-05-15 12:54:30,487 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-15 12:54:30,661 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=False, att_gates=False, params=38.67M (trainable=38.67M)
# 2026-05-15 12:54:35,189 INFO src.train: epoch  1/1  train_loss=1.5872  val_loss=1.4202  mIoU=0.0022  pixel_acc=0.0092  (4.2s)
# 2026-05-15 12:54:35,489 INFO src.train:   saved new best (mIoU=0.0022)
# 2026-05-15 12:54:35,748 INFO src.train: Training complete. Best val mIoU=0.0022
# 2026-05-15 12:54:35,828 INFO probe: [1/1] base done in 0.1 min  best mIoU = 0.0022
# 2026-05-15 12:54:35,888 INFO probe:
# 2026-05-15 12:54:35,888 INFO probe: ==============================================================================
# 2026-05-15 12:54:35,889 INFO probe: Probe complete in 0.1 min
# 2026-05-15 12:54:35,889 INFO probe:
# 2026-05-15 12:54:35,889 INFO probe: config     | attention | transformer | best mIoU | time min | status
# 2026-05-15 12:54:35,889 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 12:54:35,889 INFO probe: base       | False     | False       | 0.0022    |      0.1 | ok
# 2026-05-15 12:54:35,889 INFO probe: ==============================================================================
# 2026-05-15 12:54:35,889 INFO probe: Summary saved to /kaggle/working/smoke_test/summary.json
# Smoke test passed -- proceeding to the full probe.

# %% [markdown]
# ## 6. Full probe — 4 configurations
#
# Sequential training of all four configs into `PROBE_OUTPUT_DIR`. Each config
# writes its own `metrics.csv`, `checkpoint_best.pt`, `checkpoint_last.pt`, and
# `config.json`. A top-level `summary.json` aggregates best val mIoU per config.
#
# Progress is logged line-by-line. **Each line is also visible in the Kaggle log
# tab** while "Save & Run All" is running, so you can monitor without keeping
# the browser tab open.

# %%
import subprocess
import time

cmd = [
    'python', '-u', 'scripts/probe_architectures.py',
    '--epochs', str(EPOCHS),
    '--subset', str(SUBSET),
    '--batch-size', str(BATCH_SIZE),
    '--num-workers', str(NUM_WORKERS),
    '--lr', str(LR),
    '--augmentation', AUGMENTATION,
    '--loss', LOSS,
    '--focal-gamma', str(FOCAL_GAMMA),
    '--seed', str(SEED),
    '--device', 'cuda',
    '--configs', CONFIGS,
    '--output-dir', PROBE_OUTPUT_DIR,
]

print('Launching probe:')
print(' ', ' '.join(cmd))
print()

t0 = time.time()
result = subprocess.run(cmd)
elapsed_min = (time.time() - t0) / 60
print(f'\nProbe finished in {elapsed_min:.1f} min  (exit code = {result.returncode})')
if result.returncode != 0:
    print('WARNING: at least one config failed; check summary.json for details.')
# Out:
# Launching probe:
#   python -u scripts/probe_architectures.py --epochs 10 --subset 600 --batch-size 8 --num-workers 4 --lr 0.0001 --augmentation A --loss focal --focal-gamma 2.0 --seed 42 --device cuda --configs base,att,trans,att_trans --output-dir /kaggle/working/probe_1778849646
# 2026-05-15 12:54:42,541 INFO probe: ==============================================================================
# 2026-05-15 12:54:42,541 INFO probe: Architecture probe: 4 config(s)  device=cuda  epochs=10  subset=600  batch=8  loss=focal  aug=A
# 2026-05-15 12:54:42,541 INFO probe: Output: /kaggle/working/probe_1778849646
# 2026-05-15 12:54:42,542 INFO probe: ==============================================================================
# 2026-05-15 12:54:42,542 INFO probe:
# 2026-05-15 12:54:42,542 INFO probe: [1/4] base  (attention=False, transformer=False)
# 2026-05-15 12:54:42,542 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 12:54:42,543 INFO src.train: Device: cuda
# 2026-05-15 12:54:42,544 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 12:54:42,600 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 12:54:44,376 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-15 12:54:44,548 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=False, att_gates=False, params=38.67M (trainable=38.67M)
# 2026-05-15 12:58:47,493 INFO src.train: epoch  1/10  train_loss=0.5163  val_loss=0.2338  mIoU=0.3821  pixel_acc=0.9227  (242.6s)
# 2026-05-15 12:58:47,674 INFO src.train:   saved new best (mIoU=0.3821)
# 2026-05-15 13:02:51,837 INFO src.train: epoch  2/10  train_loss=0.2115  val_loss=0.1495  mIoU=0.4969  pixel_acc=0.9528  (244.2s)
# 2026-05-15 13:02:52,126 INFO src.train:   saved new best (mIoU=0.4969)
# 2026-05-15 13:06:56,704 INFO src.train: epoch  3/10  train_loss=0.1415  val_loss=0.1186  mIoU=0.5069  pixel_acc=0.9557  (244.6s)
# 2026-05-15 13:06:56,981 INFO src.train:   saved new best (mIoU=0.5069)
# 2026-05-15 13:11:00,862 INFO src.train: epoch  4/10  train_loss=0.1144  val_loss=0.1007  mIoU=0.5105  pixel_acc=0.9586  (243.9s)
# 2026-05-15 13:11:01,147 INFO src.train:   saved new best (mIoU=0.5105)
# 2026-05-15 13:15:05,650 INFO src.train: epoch  5/10  train_loss=0.0957  val_loss=0.0873  mIoU=0.5134  pixel_acc=0.9611  (244.5s)
# 2026-05-15 13:15:05,935 INFO src.train:   saved new best (mIoU=0.5134)
# 2026-05-15 13:19:10,461 INFO src.train: epoch  6/10  train_loss=0.0844  val_loss=0.0822  mIoU=0.5147  pixel_acc=0.9617  (244.5s)
# 2026-05-15 13:19:10,741 INFO src.train:   saved new best (mIoU=0.5147)
# 2026-05-15 13:23:15,226 INFO src.train: epoch  7/10  train_loss=0.0756  val_loss=0.0725  mIoU=0.5547  pixel_acc=0.9652  (244.5s)
# 2026-05-15 13:23:15,481 INFO src.train:   saved new best (mIoU=0.5547)
# 2026-05-15 13:27:18,931 INFO src.train: epoch  8/10  train_loss=0.0679  val_loss=0.0711  mIoU=0.5507  pixel_acc=0.9654  (243.4s)
# 2026-05-15 13:31:22,702 INFO src.train: epoch  9/10  train_loss=0.0628  val_loss=0.0676  mIoU=0.5744  pixel_acc=0.9672  (243.8s)
# 2026-05-15 13:31:22,987 INFO src.train:   saved new best (mIoU=0.5744)
# 2026-05-15 13:35:27,810 INFO src.train: epoch 10/10  train_loss=0.0601  val_loss=0.0676  mIoU=0.5794  pixel_acc=0.9673  (244.8s)
# 2026-05-15 13:35:28,075 INFO src.train:   saved new best (mIoU=0.5794)
# 2026-05-15 13:35:28,246 INFO src.train: Training complete. Best val mIoU=0.5794
# 2026-05-15 13:35:28,488 INFO probe: [1/4] base done in 40.8 min  best mIoU = 0.5794
# 2026-05-15 13:35:28,536 INFO probe:
# 2026-05-15 13:35:28,537 INFO probe: [2/4] att  (attention=True, transformer=False)
# 2026-05-15 13:35:28,537 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 13:35:28,538 INFO src.train: Device: cuda
# 2026-05-15 13:35:28,538 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 13:35:28,541 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 13:35:30,300 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-15 13:35:30,431 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=False, att_gates=True, params=39.28M (trainable=39.28M)
# 2026-05-15 13:35:35,319 ERROR probe: [2/4] att FAILED after 0.1 min
# Traceback (most recent call last):
#   File "/kaggle/working/massmind-segmentation/scripts/probe_architectures.py", line 206, in main
#     run_training(cfg, config_out)
#   File "/kaggle/working/massmind-segmentation/src/train.py", line 288, in run_training
#     train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/massmind-segmentation/src/train.py", line 178, in train_one_epoch
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 630, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 364, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 865, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 640.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 369.81 MiB is free. Including non-PyTorch memory, this process has 14.20 GiB memory in use. Of the allocated memory 12.66 GiB is allocated by PyTorch, and 1.41 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-05-15 13:35:35,380 INFO probe:
# 2026-05-15 13:35:35,380 INFO probe: [3/4] trans  (attention=False, transformer=True)
# 2026-05-15 13:35:35,380 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 13:35:35,381 INFO src.train: Device: cuda
# 2026-05-15 13:35:35,382 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 13:35:35,384 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 13:35:37,162 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# /kaggle/working/massmind-segmentation/src/models/_transformer_bottleneck.py:77: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(layer, num_layers=num_layers)
# 2026-05-15 13:35:37,303 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=True, att_gates=False, params=38.19M (trainable=38.19M)
# 2026-05-15 13:39:44,171 INFO src.train: epoch  1/10  train_loss=0.4317  val_loss=0.1853  mIoU=0.4663  pixel_acc=0.9425  (246.8s)
# 2026-05-15 13:39:44,341 INFO src.train:   saved new best (mIoU=0.4663)
# 2026-05-15 13:43:49,797 INFO src.train: epoch  2/10  train_loss=0.1553  val_loss=0.1259  mIoU=0.4976  pixel_acc=0.9535  (245.5s)
# 2026-05-15 13:43:50,069 INFO src.train:   saved new best (mIoU=0.4976)
# 2026-05-15 13:47:56,668 INFO src.train: epoch  3/10  train_loss=0.1262  val_loss=0.1038  mIoU=0.5136  pixel_acc=0.9570  (246.6s)
# 2026-05-15 13:47:56,953 INFO src.train:   saved new best (mIoU=0.5136)
# 2026-05-15 13:52:03,397 INFO src.train: epoch  4/10  train_loss=0.1017  val_loss=0.0907  mIoU=0.5274  pixel_acc=0.9599  (246.4s)
# 2026-05-15 13:52:03,657 INFO src.train:   saved new best (mIoU=0.5274)
# 2026-05-15 13:56:10,542 INFO src.train: epoch  5/10  train_loss=0.0796  val_loss=0.0731  mIoU=0.5572  pixel_acc=0.9642  (246.9s)
# 2026-05-15 13:56:10,809 INFO src.train:   saved new best (mIoU=0.5572)
# 2026-05-15 14:00:17,338 INFO src.train: epoch  6/10  train_loss=0.0682  val_loss=0.0711  mIoU=0.6116  pixel_acc=0.9653  (246.5s)
# 2026-05-15 14:00:17,613 INFO src.train:   saved new best (mIoU=0.6116)
# 2026-05-15 14:04:23,135 INFO src.train: epoch  7/10  train_loss=0.0608  val_loss=0.0653  mIoU=0.6264  pixel_acc=0.9661  (245.5s)
# 2026-05-15 14:04:23,387 INFO src.train:   saved new best (mIoU=0.6264)
# 2026-05-15 14:08:29,999 INFO src.train: epoch  8/10  train_loss=0.0520  val_loss=0.0591  mIoU=0.6377  pixel_acc=0.9684  (246.6s)
# 2026-05-15 14:08:30,261 INFO src.train:   saved new best (mIoU=0.6377)
# 2026-05-15 14:12:36,079 INFO src.train: epoch  9/10  train_loss=0.0476  val_loss=0.0557  mIoU=0.6392  pixel_acc=0.9703  (245.8s)
# 2026-05-15 14:12:36,374 INFO src.train:   saved new best (mIoU=0.6392)
# 2026-05-15 14:16:43,306 INFO src.train: epoch 10/10  train_loss=0.0467  val_loss=0.0557  mIoU=0.6404  pixel_acc=0.9706  (246.9s)
# 2026-05-15 14:16:43,563 INFO src.train:   saved new best (mIoU=0.6404)
# 2026-05-15 14:16:43,731 INFO src.train: Training complete. Best val mIoU=0.6404
# 2026-05-15 14:16:43,955 INFO probe: [3/4] trans done in 41.1 min  best mIoU = 0.6404
# 2026-05-15 14:16:44,009 INFO probe:
# 2026-05-15 14:16:44,009 INFO probe: [4/4] att_trans  (attention=True, transformer=True)
# 2026-05-15 14:16:44,009 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 14:16:44,010 INFO src.train: Device: cuda
# 2026-05-15 14:16:44,011 INFO src.train: Subsetting training set to first 600 files.
# 2026-05-15 14:16:44,013 INFO src.train: train batches=75 (n=600)  val batches=19 (n=150)  norm: mean=0.5067 std=0.1960
# 2026-05-15 14:16:45,737 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-15 14:16:45,873 INFO src.models.unet_vgg16_ext: Built VGG16UNetExt: in_channels=1, classes=7, weights=imagenet, trans_bottleneck=True, att_gates=True, params=38.80M (trainable=38.80M)
# 2026-05-15 14:16:50,745 ERROR probe: [4/4] att_trans FAILED after 0.1 min
# Traceback (most recent call last):
#   File "/kaggle/working/massmind-segmentation/scripts/probe_architectures.py", line 206, in main
#     run_training(cfg, config_out)
#   File "/kaggle/working/massmind-segmentation/src/train.py", line 288, in run_training
#     train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/massmind-segmentation/src/train.py", line 178, in train_one_epoch
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 630, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 364, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 865, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 640.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 131.81 MiB is free. Including non-PyTorch memory, this process has 14.43 GiB memory in use. Of the allocated memory 12.78 GiB is allocated by PyTorch, and 1.51 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-05-15 14:16:50,806 INFO probe:
# 2026-05-15 14:16:50,806 INFO probe: ==============================================================================
# 2026-05-15 14:16:50,806 INFO probe: Probe complete in 82.1 min
# 2026-05-15 14:16:50,806 INFO probe:
# 2026-05-15 14:16:50,806 INFO probe: config     | attention | transformer | best mIoU | time min | status
# 2026-05-15 14:16:50,807 INFO probe: ------------------------------------------------------------------------------
# 2026-05-15 14:16:50,807 INFO probe: base       | False     | False       | 0.5794    |     40.8 | ok
# 2026-05-15 14:16:50,807 INFO probe: att        | True      | False       |   nan     |      0.1 | failed
# 2026-05-15 14:16:50,807 INFO probe: trans      | False     | True        | 0.6404    |     41.1 | ok
# 2026-05-15 14:16:50,807 INFO probe: att_trans  | True      | True        |   nan     |      0.1 | failed
# 2026-05-15 14:16:50,807 INFO probe: ==============================================================================
# 2026-05-15 14:16:50,807 INFO probe: Summary saved to /kaggle/working/probe_1778849646/summary.json
# Probe finished in 82.3 min  (exit code = 1)
# WARNING: at least one config failed; check summary.json for details.

# %% [markdown]
# ## 7. Summary table + training curves
#
# Loads `summary.json` and the per-config `metrics.csv` files, prints a comparison
# table, and plots train/val loss + val mIoU per epoch for each config.

# %%
import json
from pathlib import Path

import pandas as pd

summary = json.loads(Path(PROBE_OUTPUT_DIR, 'summary.json').read_text())

rows = []
for r in summary['results']:
    rows.append({
        'config':       r['tag'],
        'attention':    r['use_attention_gates'],
        'transformer':  r['use_transformer_bottleneck'],
        'best_mIoU':    r['best_val_miou'],
        'time (min)':   round(r['elapsed_s'] / 60, 1),
        'status':       r['status'],
    })
df = pd.DataFrame(rows)
print(df.to_string(index=False))

print(f"\nTotal probe time: {summary['elapsed_total_s']/60:.1f} min")
# Out:
#    config  attention  transformer  best_mIoU  time (min) status
#      base      False        False    0.57941        40.8     ok
#       att       True        False        NaN         0.1 failed
#     trans      False         True    0.64037        41.1     ok
# att_trans       True         True        NaN         0.1 failed
#
# Total probe time: 82.1 min

# %%
import csv
from pathlib import Path

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

for r in summary['results']:
    if r['status'] != 'ok':
        continue
    metrics_csv = Path(r['config_dir']) / 'metrics.csv'
    if not metrics_csv.exists():
        continue
    epochs, tloss, vloss, mious = [], [], [], []
    with metrics_csv.open() as f:
        for row in csv.DictReader(f):
            epochs.append(int(row['epoch']))
            tloss.append(float(row['train_loss']))
            vloss.append(float(row['val_loss']))
            mious.append(float(row['mIoU']))
    axes[0].plot(epochs, vloss, marker='o', markersize=3, label=r['tag'])
    axes[1].plot(epochs, mious, marker='o', markersize=3, label=r['tag'])

axes[0].set_title('val loss');  axes[0].set_xlabel('epoch'); axes[0].set_ylabel('loss')
axes[1].set_title('val mIoU'); axes[1].set_xlabel('epoch'); axes[1].set_ylabel('mIoU')
for ax in axes:
    ax.grid(alpha=0.3); ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Per-class IoU breakdown
#
# MassMIND's interesting question is `living_obs` (0.05 % of pixels). The summary
# table only shows mIoU; this cell pulls the per-class IoU at each config's best epoch.

# %%
import csv
from pathlib import Path

import pandas as pd

CLASS_NAMES = ['sky', 'water', 'bridge', 'obstacle', 'living_obs', 'background', 'self']

per_class_rows = []
for r in summary['results']:
    if r['status'] != 'ok':
        continue
    metrics_csv = Path(r['config_dir']) / 'metrics.csv'
    if not metrics_csv.exists():
        continue
    best_row = None
    best_miou = -1.0
    with metrics_csv.open() as f:
        for row in csv.DictReader(f):
            v = float(row['mIoU'])
            if v > best_miou:
                best_miou = v
                best_row = row
    if best_row is None:
        continue
    entry = {'config': r['tag'], 'epoch': int(best_row['epoch']), 'mIoU': best_miou}
    for name in CLASS_NAMES:
        entry[name] = float(best_row.get(f'iou_{name}', float('nan')))
    per_class_rows.append(entry)

per_class = pd.DataFrame(per_class_rows)
print(per_class.to_string(index=False))
# Out:
# config  epoch    mIoU     sky   water  bridge  obstacle  living_obs  background    self
#   base     10 0.57941 0.98337 0.98168 0.32994   0.05876         0.0     0.81307 0.88903
#  trans     10 0.64037 0.98403 0.98261 0.42429   0.35076         0.0     0.82554 0.91537

# %% [markdown]
# ## 9. Package outputs for download
#
# Zips the probe directory into `/kaggle/working/probe_<timestamp>.zip`. The zip
# is automatically published to the **Output tab** of the saved version — click
# "Download All" to grab everything (checkpoints + metrics + summary + plots).

# %%
import shutil
from pathlib import Path

src_dir = Path(PROBE_OUTPUT_DIR)
archive = shutil.make_archive(str(src_dir), 'zip', root_dir=src_dir.parent, base_dir=src_dir.name)
print('Wrote archive:', archive)
print('Size (MB):  ', round(Path(archive).stat().st_size / 1e6, 1))
# Out:
# Wrote archive: /kaggle/working/probe_1778849646.zip
# Size (MB):   569.0
