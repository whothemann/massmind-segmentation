# %% [markdown]
# # MassMIND Segmentation — Colab Training
#
# Runs the U-Net + VGG-16 baseline on a Colab GPU for each of the three augmentation pipelines (A, B, C) and produces a comparison of their training curves and final per-class IoU.
#
# **Prerequisites**
#
# 1. **GPU runtime**: Runtime → Change runtime type → T4 GPU (or better).
# 2. **Private repo access**: have a GitHub Personal Access Token with `repo` scope ready (github.com → Settings → Developer Settings → Personal access tokens). You'll be prompted for it in the clone cell — it never gets written to disk or the notebook output.
# 3. **(Optional) Google Drive**: if you want checkpoints to survive the session ending, run the optional Drive-mount cell below.
#
# **Expected runtime**: ~30–60 min per config on a T4 (30 epochs × 2042 images). All three configs back-to-back fit comfortably inside Colab's free 12-hour session limit.

# %% [markdown]
# ## 0. Config
#
# Edit this cell to change which configs to run, epochs, batch size, etc.

# %%
REPO_URL_HTTPS = 'https://github.com/whothemann/massmind-segmentation.git'  # <-- EDIT ME
REPO_BRANCH = 'main'
REPO_DIR = 'massmind-segmentation'

# Training
EPOCHS = 20         # 30 if you have time -- 20 fits comfortably in one Colab session
BATCH_SIZE = 16     # T4 has 16 GB; this batch size keeps GPU well-utilized
LR = 1e-4

# Persistence (optional). Set both to None to keep everything in the ephemeral runtime.
# NOTE: writes only work under /content/drive/MyDrive/... ; /content/drive itself is read-only.
DRIVE_RUNS_DIR = None   # e.g. '/content/drive/MyDrive/massmind_runs'
DRIVE_HF_CACHE = None   # e.g. '/content/drive/MyDrive/hf_cache' -- avoids re-downloading VGG-16 weights

# %% [markdown]
# ## 1. Clone the repository
#
# You'll be prompted for a GitHub Personal Access Token. The token is read via `getpass` so it does not get echoed or saved into the notebook output.

# %%
import os
import getpass
import subprocess
from pathlib import Path

if Path(REPO_DIR).exists():
    print(f'{REPO_DIR} already present — pulling latest from {REPO_BRANCH}')
    subprocess.run(['git', '-C', REPO_DIR, 'fetch', 'origin'], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'checkout', REPO_BRANCH], check=True)
    subprocess.run(['git', '-C', REPO_DIR, 'pull', '--ff-only'], check=True)
else:
    token = getpass.getpass('GitHub PAT (repo scope): ').strip()
    if not token:
        raise RuntimeError('No token provided.')
    # Inject the token into the HTTPS URL only for this single git operation.
    auth_url = REPO_URL_HTTPS.replace('https://', f'https://x-access-token:{token}@')
    subprocess.run(['git', 'clone', '-b', REPO_BRANCH, auth_url, REPO_DIR], check=True)
    # Rewrite the remote without the token so it isn't stored in .git/config.
    subprocess.run(['git', '-C', REPO_DIR, 'remote', 'set-url', 'origin', REPO_URL_HTTPS], check=True)
    del token, auth_url

os.chdir(REPO_DIR)
print('cwd:', os.getcwd())
# Out:
# GitHub PAT (repo scope):  ········
# Cloning into 'massmind-segmentation'...
# cwd: /kaggle/working/massmind-segmentation

# %% [markdown]
# ## 2. Install dependencies
#
# Colab T4 ships with a recent torch + CUDA stack pre-installed, so this step mostly pulls albumentations / smp / gdown / opencv-headless. ~1–2 minutes.

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 95.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.9/261.9 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 3.10.2 requires jupyterlab<4.0.0a0,>=3.1.0, but you have jupyterlab 4.5.7 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.

# %% [markdown]
# ## 3. GPU sanity check

# %%
import torch
print('torch        :', torch.__version__)
print('cuda available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('device       :', torch.cuda.get_device_name(0))
    print('vram (GB)    :', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1))
# !nvidia-smi --query-gpu=name,memory.total,memory.used,driver_version --format=csv
# Out:
# torch        : 2.10.0+cu128
# cuda available: True
# device       : Tesla T4
# vram (GB)    : 15.6
# name, memory.total [MiB], memory.used [MiB], driver_version
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08
# Tesla T4, 15360 MiB, 3 MiB, 580.105.08

# %% [markdown]
# ## 4. (Optional) Mount Google Drive for persistence
#
# If `DRIVE_RUNS_DIR` is set in the config cell, run this to mount Drive and redirect run outputs + HuggingFace cache there. Otherwise everything lives in the ephemeral Colab runtime — fine for one session, gone on disconnect.

# %%
if DRIVE_RUNS_DIR or DRIVE_HF_CACHE:
    from google.colab import drive
    drive.mount('/content/drive')
    if DRIVE_RUNS_DIR:
        Path(DRIVE_RUNS_DIR).mkdir(parents=True, exist_ok=True)
        print('Run outputs will be saved under:', DRIVE_RUNS_DIR)
    if DRIVE_HF_CACHE:
        Path(DRIVE_HF_CACHE).mkdir(parents=True, exist_ok=True)
        os.environ['HF_HOME'] = DRIVE_HF_CACHE
        print('HF cache redirected to:', DRIVE_HF_CACHE)
else:
    print('No Drive paths set — running ephemerally.')
# Out:
# No Drive paths set — running ephemerally.

# %% [markdown]
# ## 5. Download dataset and prepare splits + stats
#
# Idempotent — re-running just verifies the files are present. ~1–2 min the first time (Google Drive download).

# %%
# !python scripts/download.py
# !python -m src.splits
# !python -m src.stats
# Out:
# 2026-05-11 23:29:20,490 INFO __main__: Downloading drive id=1T572f0oqy5JmuTvVEwkSUeXLWOSHl4hL -> /kaggle/working/massmind-segmentation/data/massmind/_archives/images.zip
# Downloading...
# From (original): https://drive.google.com/uc?id=1T572f0oqy5JmuTvVEwkSUeXLWOSHl4hL
# From (redirected): https://drive.google.com/uc?id=1T572f0oqy5JmuTvVEwkSUeXLWOSHl4hL&confirm=t&uuid=361f812f-c537-430a-8880-d9b75232bace
# To: /kaggle/working/massmind-segmentation/data/massmind/_archives/images.zip
# 100%|█████████████████████████████████████████| 434M/434M [00:03<00:00, 124MB/s]
# 2026-05-11 23:29:25,723 INFO __main__: Downloading drive id=1pHp480_Q-s72RoDf1nD7ERzsv9yZTDE1 -> /kaggle/working/massmind-segmentation/data/massmind/_archives/masks.zip
# Downloading...
# From: https://drive.google.com/uc?id=1pHp480_Q-s72RoDf1nD7ERzsv9yZTDE1
# To: /kaggle/working/massmind-segmentation/data/massmind/_archives/masks.zip
# 100%|███████████████████████████████████████| 7.25M/7.25M [00:00<00:00, 146MB/s]
# 2026-05-11 23:29:28,070 INFO __main__: Extracting images.zip -> /kaggle/working/massmind-segmentation/data/massmind/data
# 2026-05-11 23:29:29,244 INFO __main__: Extracting masks.zip -> /kaggle/working/massmind-segmentation/data/massmind/mask
# 2026-05-11 23:29:29,759 INFO __main__: Found 2916 images in /kaggle/working/massmind-segmentation/data/massmind/data
# 2026-05-11 23:29:29,760 INFO __main__: Found 2916 masks  in /kaggle/working/massmind-segmentation/data/massmind/mask
# 2026-05-11 23:29:29,760 INFO __main__: Done. Dataset is at /kaggle/working/massmind-segmentation/data/massmind
# 2026-05-11 23:29:29,760 INFO __main__: Removing archive directory /kaggle/working/massmind-segmentation/data/massmind/_archives
# 2026-05-11 23:29:30,113 INFO __main__: Found 2916 paired image/mask files.
# 2026-05-11 23:29:30,122 INFO __main__: Stratifying across 26 capture sessions.
# 2026-05-11 23:29:30,125 INFO __main__: Wrote split to /kaggle/working/massmind-segmentation/data/splits/split.json
# 2026-05-11 23:29:30,125 INFO __main__:   train=2042  val=583  test=291
# 2026-05-11 23:29:30,422 INFO __main__: Computing mean/std over 2042 training images
# stats: 100%|██████████████████████████████| 2042/2042 [00:10<00:00, 197.85img/s]
# 2026-05-11 23:29:40,751 INFO __main__: mean = 0.506746
# 2026-05-11 23:29:40,751 INFO __main__: std  = 0.195996
# 2026-05-11 23:29:40,751 INFO __main__: Wrote stats to /kaggle/working/massmind-segmentation/data/splits/stats.json

# %% [markdown]
# ## 6. Train
#
# Runs are split into three separate cells (A, B, C) so you can monitor each one independently and re-run a single config without redoing the others. The helper cell below defines `run_training(aug)`, which:
#
# - streams the trainer's stdout line by line,
# - shows a `tqdm` progress bar with the current / total epoch,
# - updates a live loss + mIoU plot at the end of each epoch.
#
# Each run dumps `runs/unet_vgg16_aug<X>_<ts>/` with checkpoints, `metrics.csv`, and `config.json`. If `DRIVE_RUNS_DIR` is set, the run directory is also copied to Drive after the run completes.

# %%
import re
import shutil
import subprocess
import time
from pathlib import Path

import matplotlib.pyplot as plt
from IPython.display import display
from tqdm.notebook import tqdm

# Will be populated by the per-augmentation cells below.
run_dirs = {}

# Matches the per-epoch log line emitted by src.train, e.g.:
#   epoch 12/30  train_loss=0.4321  val_loss=0.3987  mIoU=0.6541  pixel_acc=0.8123  (45.3s)
_EPOCH_RE = re.compile(
    r"epoch\s+(\d+)/(\d+)\s+train_loss=([\d.eE+-]+)\s+val_loss=([\d.eE+-]+)\s+mIoU=([\d.eE+-]+)"
)

# Colab free T4 only has 2 vCPUs; the trainer's CUDA default is 4 and
# oversubscribes, slowing dataloading. Match it to the actual core count.
NUM_WORKERS = 4


def _sync_to_drive(out_dir):
    """Copy the run dir to Drive (idempotent). Swallow errors so the run continues."""
    if not DRIVE_RUNS_DIR:
        return
    drive_path = Path(DRIVE_RUNS_DIR) / Path(out_dir).name
    try:
        shutil.copytree(out_dir, drive_path, dirs_exist_ok=True)
    except Exception as e:
        print(f"  [drive sync failed: {e}]")


def run_training(aug):
    """Launch src.train for one augmentation with a live progress bar + plot.

    Returns the output directory path on success, or raises on non-zero exit.
    Syncs the run dir to Drive after every completed epoch (when DRIVE_RUNS_DIR
    is set) so a runtime crash leaves the latest checkpoint + metrics behind.
    """
    # Defensive: kill any leftover trainer from a previous session that's still
    # holding GPU memory.
    subprocess.run(["pkill", "-9", "-f", "src.train"], check=False)

    ts = int(time.time())
    out_dir = f"runs/unet_vgg16_aug{aug}_{ts}"
    print(f"=== Training augmentation {aug} -> {out_dir} ===")

    cmd = [
        "python", "-u", "-m", "src.train",
        "--augmentation", aug,
        "--epochs", str(EPOCHS),
        "--batch-size", str(BATCH_SIZE),
        "--lr", str(LR),
        "--num-workers", str(NUM_WORKERS),
        "--output-dir", out_dir,
    ]

    pbar = tqdm(total=EPOCHS, desc=f"aug {aug}", unit="epoch")
    fig, axes = plt.subplots(1, 2, figsize=(11, 3.5))
    plot_handle = display(fig, display_id=True)
    epochs, tloss, vloss, mious = [], [], [], []

    proc = subprocess.Popen(
        cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1
    )
    try:
        for raw in proc.stdout:
            line = raw.rstrip()
            print(line)
            m = _EPOCH_RE.search(line)
            if not m:
                continue
            ep, total = int(m.group(1)), int(m.group(2))
            tl, vl, mi = float(m.group(3)), float(m.group(4)), float(m.group(5))
            epochs.append(ep); tloss.append(tl); vloss.append(vl); mious.append(mi)
            pbar.total = total
            pbar.update(ep - pbar.n)

            axes[0].clear(); axes[1].clear()
            axes[0].plot(epochs, tloss, label="train", marker="o", markersize=3)
            axes[0].plot(epochs, vloss, label="val",   marker="o", markersize=3)
            axes[0].set_title(f"aug {aug} -- loss"); axes[0].set_xlabel("epoch")
            axes[0].set_ylabel("CE loss"); axes[0].legend(); axes[0].grid(alpha=0.3)
            axes[1].plot(epochs, mious, color="C2", marker="o", markersize=3)
            axes[1].set_title(f"aug {aug} -- val mIoU"); axes[1].set_xlabel("epoch")
            axes[1].set_ylabel("mIoU"); axes[1].grid(alpha=0.3)
            fig.tight_layout()
            plot_handle.update(fig)

            # Persist after each epoch so a crash doesn't wipe progress.
            _sync_to_drive(out_dir)
    except KeyboardInterrupt:
        proc.terminate()
        raise
    finally:
        proc.wait()
        pbar.close()
        plt.close(fig)

    if proc.returncode != 0:
        raise RuntimeError(f"Training for aug {aug} exited with code {proc.returncode}")

    _sync_to_drive(out_dir)  # final sync (idempotent)
    if DRIVE_RUNS_DIR:
        print(f"Copied to Drive: {Path(DRIVE_RUNS_DIR) / Path(out_dir).name}")

    return out_dir

# %%
# Browser-side keepalive: simulates a periodic click on the Colab connect
# button so the runtime registers ongoing activity and skips the ~90 min idle
# disconnect. Run once after the helper is defined; safe to leave running.
from IPython.display import Javascript, display
display(Javascript('''
setInterval(() => {
    const btn = document.querySelector("colab-connect-button");
    if (btn) btn.click();
}, 60000);
console.log("Colab keepalive started (60s ping).");
'''))

# %% [markdown]
# ### 6a. Augmentation A
#
# Pipeline A: geometric augmentations only (random flip, scale, crop). Train and watch progress.

# %%
run_dirs['A'] = run_training('A')
# Out:
# === Training augmentation A -> runs/unet_vgg16_augA_1778542181 ===
# aug A:   0%|          | 0/20 [00:00<?, ?epoch/s]
# 2026-05-11 23:29:53,898 INFO __main__: Device: cuda
# 2026-05-11 23:29:53,902 INFO __main__: train batches=128 (n=2042)  val batches=37 (n=583)  norm: mean=0.5067 std=0.1960
# 2026-05-11 23:29:55,880 INFO httpx: HTTP Request: HEAD https://huggingface.co/smp-hub/vgg16.imagenet/resolve/49d74b799006ee252b86e25acd6f1fd8ac9a99c1/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-05-11 23:29:55,897 INFO httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/smp-hub/vgg16.imagenet/49d74b799006ee252b86e25acd6f1fd8ac9a99c1/config.json "HTTP/1.1 200 OK"
# 2026-05-11 23:29:55,916 INFO httpx: HTTP Request: GET https://huggingface.co/api/resolve-cache/models/smp-hub/vgg16.imagenet/49d74b799006ee252b86e25acd6f1fd8ac9a99c1/config.json "HTTP/1.1 200 OK"
# 2026-05-11 23:29:55,987 INFO httpx: HTTP Request: HEAD https://huggingface.co/smp-hub/vgg16.imagenet/resolve/49d74b799006ee252b86e25acd6f1fd8ac9a99c1/model.safetensors "HTTP/1.1 302 Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-05-11 23:29:55,987 WARNING huggingface_hub.utils._http: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-05-11 23:29:56,089 INFO httpx: HTTP Request: GET https://huggingface.co/api/models/smp-hub/vgg16.imagenet/xet-read-token/49d74b799006ee252b86e25acd6f1fd8ac9a99c1 "HTTP/1.1 200 OK"
# 2026-05-11 23:29:59,600 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-11 23:29:59,601 INFO src.models.unet: Built U-Net+VGG16: in_channels=1, classes=7, params=23.75M, encoder_weights=imagenet
# 2026-05-11 23:36:02,525 INFO __main__: epoch  1/20  train_loss=1.1134  val_loss=0.5794  mIoU=0.3961  pixel_acc=0.9265  (362.6s)
# 2026-05-11 23:36:02,644 INFO __main__:   saved new best (mIoU=0.3961)
# 2026-05-11 23:42:16,750 INFO __main__: epoch  2/20  train_loss=0.4531  val_loss=0.3266  mIoU=0.4417  pixel_acc=0.9416  (374.1s)
# 2026-05-11 23:42:16,952 INFO __main__:   saved new best (mIoU=0.4417)
# 2026-05-11 23:48:32,284 INFO __main__: epoch  3/20  train_loss=0.2700  val_loss=0.2148  mIoU=0.5135  pixel_acc=0.9577  (375.3s)
# 2026-05-11 23:48:32,474 INFO __main__:   saved new best (mIoU=0.5135)
# 2026-05-11 23:54:47,591 INFO __main__: epoch  4/20  train_loss=0.1887  val_loss=0.1581  mIoU=0.5258  pixel_acc=0.9628  (375.1s)
# 2026-05-11 23:54:47,759 INFO __main__:   saved new best (mIoU=0.5258)
# 2026-05-12 00:01:02,841 INFO __main__: epoch  5/20  train_loss=0.1479  val_loss=0.1316  mIoU=0.5857  pixel_acc=0.9685  (375.1s)
# 2026-05-12 00:01:03,024 INFO __main__:   saved new best (mIoU=0.5857)
# 2026-05-12 00:07:18,481 INFO __main__: epoch  6/20  train_loss=0.1323  val_loss=0.1178  mIoU=0.6036  pixel_acc=0.9711  (375.5s)
# 2026-05-12 00:07:18,683 INFO __main__:   saved new best (mIoU=0.6036)
# 2026-05-12 00:13:33,871 INFO __main__: epoch  7/20  train_loss=0.1137  val_loss=0.1260  mIoU=0.5857  pixel_acc=0.9658  (375.2s)
# 2026-05-12 00:19:47,974 INFO __main__: epoch  8/20  train_loss=0.1011  val_loss=0.0996  mIoU=0.6213  pixel_acc=0.9727  (374.1s)
# 2026-05-12 00:19:48,140 INFO __main__:   saved new best (mIoU=0.6213)
# 2026-05-12 00:26:03,696 INFO __main__: epoch  9/20  train_loss=0.0924  val_loss=0.0950  mIoU=0.6167  pixel_acc=0.9727  (375.6s)
# 2026-05-12 00:32:18,955 INFO __main__: epoch 10/20  train_loss=0.0820  val_loss=0.0833  mIoU=0.6452  pixel_acc=0.9752  (375.3s)
# 2026-05-12 00:32:19,124 INFO __main__:   saved new best (mIoU=0.6452)
# 2026-05-12 00:38:34,838 INFO __main__: epoch 11/20  train_loss=0.0751  val_loss=0.0802  mIoU=0.6978  pixel_acc=0.9793  (375.7s)
# 2026-05-12 00:38:35,015 INFO __main__:   saved new best (mIoU=0.6978)
# 2026-05-12 00:44:50,429 INFO __main__: epoch 12/20  train_loss=0.0679  val_loss=0.0763  mIoU=0.7141  pixel_acc=0.9806  (375.4s)
# 2026-05-12 00:44:50,629 INFO __main__:   saved new best (mIoU=0.7141)
# 2026-05-12 00:51:06,757 INFO __main__: epoch 13/20  train_loss=0.0625  val_loss=0.0727  mIoU=0.7280  pixel_acc=0.9814  (376.1s)
# 2026-05-12 00:51:06,936 INFO __main__:   saved new best (mIoU=0.7280)
# 2026-05-12 00:57:21,563 INFO __main__: epoch 14/20  train_loss=0.0579  val_loss=0.0703  mIoU=0.7320  pixel_acc=0.9821  (374.6s)
# 2026-05-12 00:57:21,722 INFO __main__:   saved new best (mIoU=0.7320)
# 2026-05-12 01:03:37,433 INFO __main__: epoch 15/20  train_loss=0.0542  val_loss=0.0706  mIoU=0.7317  pixel_acc=0.9821  (375.7s)
# 2026-05-12 01:09:53,148 INFO __main__: epoch 16/20  train_loss=0.0517  val_loss=0.0669  mIoU=0.7374  pixel_acc=0.9827  (375.7s)
# 2026-05-12 01:09:53,309 INFO __main__:   saved new best (mIoU=0.7374)
# 2026-05-12 01:16:08,553 INFO __main__: epoch 17/20  train_loss=0.0503  val_loss=0.0665  mIoU=0.7373  pixel_acc=0.9827  (375.2s)
# 2026-05-12 01:22:24,640 INFO __main__: epoch 18/20  train_loss=0.0495  val_loss=0.0650  mIoU=0.7388  pixel_acc=0.9828  (376.1s)
# 2026-05-12 01:22:24,809 INFO __main__:   saved new best (mIoU=0.7388)
# 2026-05-12 01:28:40,620 INFO __main__: epoch 19/20  train_loss=0.0483  val_loss=0.0662  mIoU=0.7368  pixel_acc=0.9826  (375.8s)
# 2026-05-12 01:34:56,177 INFO __main__: epoch 20/20  train_loss=0.0484  val_loss=0.0650  mIoU=0.7387  pixel_acc=0.9828  (375.6s)
# 2026-05-12 01:34:56,289 INFO __main__: Training complete. Best val mIoU=0.7388

# %% [markdown]
# ### 6b. Augmentation B
#
# Pipeline B: geometric + photometric augmentations. Train and watch progress.

# %%
run_dirs['B'] = run_training('B')
# Out:
# === Training augmentation B -> runs/unet_vgg16_augB_1778549701 ===
# aug B:   0%|          | 0/20 [00:00<?, ?epoch/s]
# 2026-05-12 01:35:06,926 INFO __main__: Device: cuda
# 2026-05-12 01:35:06,933 INFO __main__: train batches=128 (n=2042)  val batches=37 (n=583)  norm: mean=0.5067 std=0.1960
# 2026-05-12 01:35:08,770 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-12 01:35:08,771 INFO src.models.unet: Built U-Net+VGG16: in_channels=1, classes=7, params=23.75M, encoder_weights=imagenet
# 2026-05-12 01:41:26,111 INFO __main__: epoch  1/20  train_loss=1.1493  val_loss=0.6262  mIoU=0.3663  pixel_acc=0.9145  (377.0s)
# 2026-05-12 01:41:26,246 INFO __main__:   saved new best (mIoU=0.3663)
# 2026-05-12 01:47:41,270 INFO __main__: epoch  2/20  train_loss=0.4962  val_loss=0.3562  mIoU=0.4136  pixel_acc=0.9311  (375.0s)
# 2026-05-12 01:47:41,461 INFO __main__:   saved new best (mIoU=0.4136)
# 2026-05-12 01:53:56,008 INFO __main__: epoch  3/20  train_loss=0.3048  val_loss=0.2428  mIoU=0.5004  pixel_acc=0.9543  (374.5s)
# 2026-05-12 01:53:56,198 INFO __main__:   saved new best (mIoU=0.5004)
# 2026-05-12 02:00:11,118 INFO __main__: epoch  4/20  train_loss=0.2393  val_loss=0.1944  mIoU=0.5092  pixel_acc=0.9568  (374.9s)
# 2026-05-12 02:00:11,291 INFO __main__:   saved new best (mIoU=0.5092)
# 2026-05-12 02:06:27,037 INFO __main__: epoch  5/20  train_loss=0.1833  val_loss=0.1467  mIoU=0.5839  pixel_acc=0.9665  (375.7s)
# 2026-05-12 02:06:27,234 INFO __main__:   saved new best (mIoU=0.5839)
# 2026-05-12 02:12:43,490 INFO __main__: epoch  6/20  train_loss=0.1530  val_loss=0.1253  mIoU=0.6039  pixel_acc=0.9696  (376.3s)
# 2026-05-12 02:12:43,687 INFO __main__:   saved new best (mIoU=0.6039)
# 2026-05-12 02:19:01,096 INFO __main__: epoch  7/20  train_loss=0.1386  val_loss=0.1163  mIoU=0.6088  pixel_acc=0.9701  (377.4s)
# 2026-05-12 02:19:01,289 INFO __main__:   saved new best (mIoU=0.6088)
# 2026-05-12 02:25:18,384 INFO __main__: epoch  8/20  train_loss=0.1257  val_loss=0.1065  mIoU=0.6190  pixel_acc=0.9708  (377.1s)
# 2026-05-12 02:25:18,605 INFO __main__:   saved new best (mIoU=0.6190)
# 2026-05-12 02:31:34,948 INFO __main__: epoch  9/20  train_loss=0.1151  val_loss=0.0977  mIoU=0.6193  pixel_acc=0.9720  (376.3s)
# 2026-05-12 02:31:35,166 INFO __main__:   saved new best (mIoU=0.6193)
# 2026-05-12 02:37:51,460 INFO __main__: epoch 10/20  train_loss=0.1131  val_loss=0.0945  mIoU=0.6238  pixel_acc=0.9724  (376.3s)
# 2026-05-12 02:37:51,659 INFO __main__:   saved new best (mIoU=0.6238)
# 2026-05-12 02:44:08,643 INFO __main__: epoch 11/20  train_loss=0.1006  val_loss=0.0912  mIoU=0.6243  pixel_acc=0.9726  (377.0s)
# 2026-05-12 02:44:08,851 INFO __main__:   saved new best (mIoU=0.6243)
# 2026-05-12 02:50:26,008 INFO __main__: epoch 12/20  train_loss=0.0939  val_loss=0.0861  mIoU=0.6270  pixel_acc=0.9736  (377.2s)
# 2026-05-12 02:50:26,215 INFO __main__:   saved new best (mIoU=0.6270)
# 2026-05-12 02:56:43,548 INFO __main__: epoch 13/20  train_loss=0.0883  val_loss=0.0816  mIoU=0.6361  pixel_acc=0.9745  (377.3s)
# 2026-05-12 02:56:43,749 INFO __main__:   saved new best (mIoU=0.6361)
# 2026-05-12 03:03:01,818 INFO __main__: epoch 14/20  train_loss=0.0854  val_loss=0.0828  mIoU=0.6267  pixel_acc=0.9738  (378.1s)
# 2026-05-12 03:09:19,640 INFO __main__: epoch 15/20  train_loss=0.0834  val_loss=0.0778  mIoU=0.6377  pixel_acc=0.9748  (377.8s)
# 2026-05-12 03:09:19,863 INFO __main__:   saved new best (mIoU=0.6377)
# 2026-05-12 03:15:37,277 INFO __main__: epoch 16/20  train_loss=0.0779  val_loss=0.0768  mIoU=0.6384  pixel_acc=0.9751  (377.4s)
# 2026-05-12 03:15:37,496 INFO __main__:   saved new best (mIoU=0.6384)
# 2026-05-12 03:21:55,194 INFO __main__: epoch 17/20  train_loss=0.0761  val_loss=0.0768  mIoU=0.6406  pixel_acc=0.9753  (377.7s)
# 2026-05-12 03:21:55,439 INFO __main__:   saved new best (mIoU=0.6406)
# 2026-05-12 03:28:12,412 INFO __main__: epoch 18/20  train_loss=0.0774  val_loss=0.0742  mIoU=0.6414  pixel_acc=0.9755  (377.0s)
# 2026-05-12 03:28:12,671 INFO __main__:   saved new best (mIoU=0.6414)
# 2026-05-12 03:34:30,437 INFO __main__: epoch 19/20  train_loss=0.0744  val_loss=0.0750  mIoU=0.6409  pixel_acc=0.9755  (377.8s)
# 2026-05-12 03:40:48,185 INFO __main__: epoch 20/20  train_loss=0.0739  val_loss=0.0738  mIoU=0.6428  pixel_acc=0.9756  (377.7s)
# 2026-05-12 03:40:48,394 INFO __main__:   saved new best (mIoU=0.6428)
# 2026-05-12 03:40:48,516 INFO __main__: Training complete. Best val mIoU=0.6428

# %% [markdown]
# ### 6c. Augmentation C
#
# Pipeline C: minimal augmentations (normalization only). Train and watch progress.

# %%
run_dirs['C'] = run_training('C')
# Out:
# === Training augmentation C -> runs/unet_vgg16_augC_1778557250 ===
# aug C:   0%|          | 0/20 [00:00<?, ?epoch/s]
# 2026-05-12 03:40:57,541 INFO __main__: Device: cuda
# 2026-05-12 03:40:57,545 INFO __main__: train batches=128 (n=2042)  val batches=37 (n=583)  norm: mean=0.5067 std=0.1960
# 2026-05-12 03:40:59,641 INFO src.models._adapt: Adapted first conv: in=3 -> 1, out=64, kernel=(3, 3) (channel-mean init)
# 2026-05-12 03:40:59,642 INFO src.models.unet: Built U-Net+VGG16: in_channels=1, classes=7, params=23.75M, encoder_weights=imagenet
# 2026-05-12 03:47:17,905 INFO __main__: epoch  1/20  train_loss=1.1076  val_loss=0.5814  mIoU=0.4305  pixel_acc=0.9319  (378.0s)
# 2026-05-12 03:47:18,061 INFO __main__:   saved new best (mIoU=0.4305)
# 2026-05-12 03:53:33,567 INFO __main__: epoch  2/20  train_loss=0.4470  val_loss=0.3102  mIoU=0.5004  pixel_acc=0.9550  (375.5s)
# 2026-05-12 03:53:33,765 INFO __main__:   saved new best (mIoU=0.5004)
# 2026-05-12 03:59:49,675 INFO __main__: epoch  3/20  train_loss=0.2517  val_loss=0.2039  mIoU=0.5327  pixel_acc=0.9619  (375.9s)
# 2026-05-12 03:59:49,887 INFO __main__:   saved new best (mIoU=0.5327)
# 2026-05-12 04:06:05,919 INFO __main__: epoch  4/20  train_loss=0.1755  val_loss=0.1552  mIoU=0.5799  pixel_acc=0.9683  (376.0s)
# 2026-05-12 04:06:06,113 INFO __main__:   saved new best (mIoU=0.5799)
# 2026-05-12 04:12:22,984 INFO __main__: epoch  5/20  train_loss=0.1370  val_loss=0.1254  mIoU=0.6209  pixel_acc=0.9719  (376.9s)
# 2026-05-12 04:12:23,193 INFO __main__:   saved new best (mIoU=0.6209)
# 2026-05-12 04:18:39,382 INFO __main__: epoch  6/20  train_loss=0.1166  val_loss=0.1127  mIoU=0.6121  pixel_acc=0.9717  (376.2s)
# 2026-05-12 04:24:56,246 INFO __main__: epoch  7/20  train_loss=0.1012  val_loss=0.1072  mIoU=0.6292  pixel_acc=0.9720  (376.9s)
# 2026-05-12 04:24:56,459 INFO __main__:   saved new best (mIoU=0.6292)
# 2026-05-12 04:31:13,857 INFO __main__: epoch  8/20  train_loss=0.0873  val_loss=0.0950  mIoU=0.6904  pixel_acc=0.9780  (377.4s)
# 2026-05-12 04:31:14,054 INFO __main__:   saved new best (mIoU=0.6904)
# 2026-05-12 04:37:31,179 INFO __main__: epoch  9/20  train_loss=0.0766  val_loss=0.0860  mIoU=0.7077  pixel_acc=0.9790  (377.1s)
# 2026-05-12 04:37:31,393 INFO __main__:   saved new best (mIoU=0.7077)
# 2026-05-12 04:43:48,100 INFO __main__: epoch 10/20  train_loss=0.0672  val_loss=0.0839  mIoU=0.7097  pixel_acc=0.9795  (376.7s)
# 2026-05-12 04:43:48,286 INFO __main__:   saved new best (mIoU=0.7097)
# 2026-05-12 04:50:04,995 INFO __main__: epoch 11/20  train_loss=0.0584  val_loss=0.0735  mIoU=0.7360  pixel_acc=0.9822  (376.7s)
# 2026-05-12 04:50:05,232 INFO __main__:   saved new best (mIoU=0.7360)
# 2026-05-12 04:56:22,368 INFO __main__: epoch 12/20  train_loss=0.0525  val_loss=0.0719  mIoU=0.7334  pixel_acc=0.9822  (377.1s)
# 2026-05-12 05:02:39,693 INFO __main__: epoch 13/20  train_loss=0.0485  val_loss=0.0697  mIoU=0.7380  pixel_acc=0.9827  (377.3s)
# 2026-05-12 05:02:39,903 INFO __main__:   saved new best (mIoU=0.7380)
# 2026-05-12 05:08:56,480 INFO __main__: epoch 14/20  train_loss=0.0457  val_loss=0.0690  mIoU=0.7395  pixel_acc=0.9829  (376.6s)
# 2026-05-12 05:08:56,674 INFO __main__:   saved new best (mIoU=0.7395)
# 2026-05-12 05:15:13,560 INFO __main__: epoch 15/20  train_loss=0.0432  val_loss=0.0694  mIoU=0.7400  pixel_acc=0.9830  (376.9s)
# 2026-05-12 05:15:13,769 INFO __main__:   saved new best (mIoU=0.7400)
# 2026-05-12 05:21:30,586 INFO __main__: epoch 16/20  train_loss=0.0412  val_loss=0.0676  mIoU=0.7419  pixel_acc=0.9832  (376.8s)
# 2026-05-12 05:21:30,775 INFO __main__:   saved new best (mIoU=0.7419)
# 2026-05-12 05:27:47,701 INFO __main__: epoch 17/20  train_loss=0.0401  val_loss=0.0679  mIoU=0.7405  pixel_acc=0.9830  (376.9s)
# 2026-05-12 05:34:05,463 INFO __main__: epoch 18/20  train_loss=0.0393  val_loss=0.0667  mIoU=0.7425  pixel_acc=0.9832  (377.8s)
# 2026-05-12 05:34:05,664 INFO __main__:   saved new best (mIoU=0.7425)
# 2026-05-12 05:40:22,610 INFO __main__: epoch 19/20  train_loss=0.0384  val_loss=0.0671  mIoU=0.7424  pixel_acc=0.9832  (376.9s)
# 2026-05-12 05:46:39,848 INFO __main__: epoch 20/20  train_loss=0.0381  val_loss=0.0661  mIoU=0.7438  pixel_acc=0.9833  (377.2s)
# 2026-05-12 05:46:40,039 INFO __main__:   saved new best (mIoU=0.7438)
# 2026-05-12 05:46:40,173 INFO __main__: Training complete. Best val mIoU=0.7438

# %% [markdown]
# ## 7. Compare runs
#
# Loads `metrics.csv` for each completed run and overlays train/val loss + mIoU curves, plus a final per-class IoU table.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

metrics = {aug: pd.read_csv(Path(d) / 'metrics.csv') for aug, d in run_dirs.items()}

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
for aug, df in metrics.items():
    axes[0].plot(df['epoch'], df['train_loss'], label=f'{aug} train', linestyle='--')
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{aug} val')
    axes[1].plot(df['epoch'], df['mIoU'],       label=f'{aug}')
axes[0].set_title('Loss'); axes[0].set_xlabel('epoch'); axes[0].set_ylabel('CE loss'); axes[0].legend(); axes[0].grid(alpha=0.3)
axes[1].set_title('Validation mIoU'); axes[1].set_xlabel('epoch'); axes[1].set_ylabel('mIoU'); axes[1].legend(); axes[1].grid(alpha=0.3)
fig.tight_layout()

# %%
CLASS_NAMES = ['sky', 'water', 'bridge', 'obstacle', 'living_obs', 'background', 'self']
rows = []
for aug, df in metrics.items():
    # Pick the row with best val mIoU.
    best = df.loc[df['mIoU'].idxmax()]
    row = {'aug': aug, 'best_epoch': int(best['epoch']), 'mIoU': best['mIoU'], 'pixel_acc': best['pixel_acc']}
    for n in CLASS_NAMES:
        row[f'iou_{n}'] = best[f'iou_{n}']
    rows.append(row)
summary = pd.DataFrame(rows).set_index('aug')
summary
# Out:
#      best_epoch     mIoU  pixel_acc  iou_sky  iou_water  iou_bridge  \
# aug
# A            18  0.73884    0.98282  0.98570    0.98958     0.71772
# B            20  0.64276    0.97560  0.98476    0.97892     0.71937
# C            20  0.74375    0.98331  0.98568    0.98977     0.72284
#
#      iou_obstacle  iou_living_obs  iou_background  iou_self
# aug
# A         0.64083             0.0         0.89284   0.94522
# B         0.00008             0.0         0.87660   0.93956
# C         0.66590             0.0         0.89607   0.94600

# %% [markdown]
# ## 8. Push run outputs back to the repo (optional)
#
# If you want `metrics.csv` + `config.json` in the repo for reproducibility (without committing the heavy `.pt` checkpoints), uncomment and run. The `.gitignore` already excludes `runs/`, so we have to add the metrics files explicitly with `git add -f`.

# %%
COMMIT_RESULTS = True
if COMMIT_RESULTS:
     for aug, d in run_dirs.items():
         # !git add -f {d}/metrics.csv {d}/config.json
     # !git -c user.email='colab@local' -c user.name='colab' commit -m 'add training metrics from Colab run'
     # You will need to push manually with a PAT — see the clone cell pattern.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/1885646430.py in <cell line: 0>()
#       1 COMMIT_RESULTS = True
#       2 if COMMIT_RESULTS:
# ----> 3      for aug, d in run_dirs.items():
#       4          get_ipython().system('git add -f {d}/metrics.csv {d}/config.json')
#       5      get_ipython().system("git -c user.email='colab@local' -c user.name='colab' commit -m 'add training metrics from Colab run'")
#
# NameError: name 'run_dirs' is not defined
